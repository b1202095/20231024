# %%
h = int(input())
for i in range(1,h):
  if i >= (h-5):
    print(' '*(h-8)+'*'*3)
  else:
    print(' '*(h-6-i)+'*'*i,end = '')
    print('*'*(i-1))
# Out:
# 15
#         *
#        ***
#       *****
#      *******
#     *********
#    ***********
#   *************
#  ***************
# *****************
#        ***
#        ***
#        ***
#        ***
#        ***

# %%
def a(h,w):
 try:
  return (w/((0.01*h)**2))
 except:
  return ('輸入錯誤')
 h = int(input('輸入身高(公分'))
 w = int(input("輸入體重(公斤"))
